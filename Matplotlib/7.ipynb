# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
photoupload = np.array([10,2,15,30,5,24,12,7,18,4])
likes = np.array([50,5,80,40,20,50,60,30,60,10])
plt.plot(photoupload, likes,linestyle="solid",c="grey")
plt.scatter(photoupload, likes,c='red')
plt.show()
