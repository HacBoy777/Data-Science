# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.array([6,4,2,15,1])
plt.plot(y,linestyle='solid')

# %%
plt.plot(y,linestyle='dotted')

# %%
plt.plot(y,linestyle='dashed')

# %%
plt.plot(y,linestyle='dashdot')
