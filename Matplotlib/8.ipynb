# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
student = np.array(['A', 'B', 'C', 'D'])
height = np.array([5.1, 6.2, 5.9, 5.7])

# %%
plt.bar(student, height)
plt.show()

# %%
cars = np.array(['BMW', 'Audi', 'Ford', 'Tesla'])
dist = np.array([20, 15, 30, 25])
plt.barh(cars, dist, color ='orange')
plt.show()
