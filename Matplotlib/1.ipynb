# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib as plt
print(plt.__version__)
# Out:
# 3.10.0

# %%
x = np.array([10, 25, 30, 45, 50])
y = np.array([10, 12, 16, 40, 20])
plt.plot(x, y)
plt.show()
